# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.patches import Circle
import os
import shutil
from PIL import Image

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.patches import Circle
import os
import shutil
from PIL import Image

def generate_random_dot_motion(num_dots, coherence, dot_size, dot_speed, direction, duration, frame_rate, screen_size, circle_radius, output_filename):
    # Convert direction to radians
    direction_rad = np.deg2rad(direction)

    # Initialize dot positions
    theta = 2 * np.pi * np.random.rand(num_dots)
    r = circle_radius * np.sqrt(np.random.rand(num_dots))
    dot_positions = np.column_stack((r * np.cos(theta), r * np.sin(theta)))

    # Initialize dot motion
    dx = dot_speed * np.cos(direction_rad)
    dy = -dot_speed * np.sin(direction_rad)

    # Create figure and axes
    fig, ax = plt.subplots()
    ax.set_xlim(-circle_radius, circle_radius)
    ax.set_ylim(-circle_radius, circle_radius)
    ax.set_aspect('equal')
    ax.axis('off')
    fig.patch.set_facecolor('black')
    ax.set_facecolor('black')

    # Plot initial dots
    dots = ax.scatter(dot_positions[:, 0], dot_positions[:, 1], s=dot_size, color='white')
    circle = Circle((0, 0), circle_radius, edgecolor='white', facecolor='none', linewidth=0.5)
    ax.add_patch(circle)

    # Number of frames
    num_frames = int(duration * frame_rate)

    def update(frame):
        nonlocal dot_positions

        # Determine which dots are coherent
        coherent_dots = np.random.rand(num_dots) < coherence

        # Update positions for coherent dots
        dot_positions[coherent_dots, 0] += dx
        dot_positions[coherent_dots, 1] += dy

        # Update positions for incoherent dots
        dot_positions[~coherent_dots] += (np.random.rand(np.sum(~coherent_dots), 2) - 0.5) * 2 * dot_speed

        # Wrap around dots that move out of the circular region
        #distances = np.sqrt(dot_positions[:, 0]**2 + dot_positions[:, 1]**2)
        #out_of_bounds = distances > circle_radius
        #theta_out = 2 * np.pi * np.random.rand(np.sum(out_of_bounds))
        #r_out = circle_radius * np.sqrt(np.random.rand(np.sum(out_of_bounds)))
        #dot_positions[out_of_bounds] = np.column_stack((r_out * np.cos(theta_out), r_out * np.sin(theta_out)))
        # Wrap around dots that move out of the circular region
        distances = np.sqrt(dot_positions[:, 0]**2 + dot_positions[:, 1]**2)
        out_of_bounds = distances > circle_radius
        # Calculate new positions for out-of-bounds dots
        dot_positions[out_of_bounds, 0] *= -1  # Reflect x-coordinate
        dot_positions[out_of_bounds, 1] *= -1  # Reflect y-coordinate
        # Check if reflected dots are still out of bounds and remove them
        distances = np.sqrt(dot_positions[:, 0]**2 + dot_positions[:, 1]**2)
        out_of_bounds = distances > circle_radius
        
        colors = np.array(['white'] * num_dots)
        colors[out_of_bounds] = 'black'

        # Update dot positions and colors in plot
        dots.set_offsets(dot_positions)
        dots.set_color(colors)


        return dots,

    # Create animation
    ani = animation.FuncAnimation(fig, update, frames=num_frames, blit=True)

    # Temporary directory to save frames
    temp_dir = "temp_frames"
    if os.path.exists(temp_dir):
        shutil.rmtree(temp_dir)
    os.makedirs(temp_dir)

    # Save each frame as an image
    for i in range(num_frames):
        update(i)
        plt.savefig(f"{temp_dir}/frame_{i:04d}.png", dpi=100)

    plt.close()

    # Convert images to MP4 using ffmpeg
    #os.system(f"ffmpeg -r {frame_rate} -i {temp_dir}/frame_%04d.png -vcodec libx264 -y random_dot_motion_circle.mp4")
    os.system(f"ffmpeg -r {frame_rate} -i {temp_dir}/frame_%04d.png -vcodec libx264 -y {output_filename}")


    # Clean up temporary frames
    shutil.rmtree(temp_dir)

# Example u

# %%
n_dots = 1000
dot_coh = .9
dot_size = 10
dot_angles = [180,270,0,90]
dot_speeds = [1,2,3,4]
dot_sets = [1]
for set in range(np.size(dot_sets)):
    for angle in range(np.size(dot_angles)):
        for speed in range(np.size(dot_speeds)):
            dot_speed = 2*dot_speeds[speed]
            dot_angle = dot_angles[angle]
            f_name = 'D' + str(angle+1) + '_S' + str(speed+1) + '_' + str(set+1) + '.mp4'
            generate_random_dot_motion(n_dots, dot_coh, dot_size, dot_speed, dot_angle, 5, 60, [800, 600], 200, f_name)
# Out:
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'temp_frames/frame_%04d.png':
#   Duration: 00:00:12.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 640x480 [SAR 3937:3937 DAR 4:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x134809400] using SAR=1/1
# [libx264 @ 0x134809400] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x134809400] profile High 4:4:4 Predictive, level 3.1, 4:4:4 8-bit
# [libx264 @ 0x134809400] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'D1_S1_1.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 640x480 [SAR 1:1 DAR 4:3], q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  301 fps=0.0 q=-1.0 Lsize=    1270kB time=00:00:04.96 bitrate=2095.3kbits/s dup=1 drop=0 speed=6.27x
# video:1266kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.345189%
# [libx264 @ 0x134809400] frame I:2     Avg QP:16.79  size: 24552
# [libx264 @ 0x134809400] frame P:76    Avg QP:27.17  size: 10912
# [libx264 @ 0x134809400] frame B:223   Avg QP:33.98  size:  1871
# [libx264 @ 0x134809400] consecutive B-frames:  0.7%  1.3%  1.0% 97.0%
# [libx264 @ 0x134809400] mb I  I16..4: 61.5%  0.0% 38.5%
# [libx264 @ 0x134809400] mb P  I16..4:  0.9%  0.0%  1.3%  P16..4:  7.7% 11.4% 16.8%  0.0%  0.0%    skip:61.8%
# [libx264 @ 0x134809400] mb B  I16..4:  0.1%  0.0%  0.0%  B16..8: 14.3%  7.9%  5.0%  direct: 3.4%  skip:69.1%  L0:46.6% L1:44.6% BI: 8.7%
# [libx264 @ 0x134809400] coded y,u,v intra: 34.5% 0.0% 0.0% inter: 8.0% 0.0% 0.0%
# [libx264 @ 0x134809400] i16 v,h,dc,p: 70% 16% 14%  0%
# [libx264 @ 0x134809400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 15% 26%  4%  8%  6%  6%  5%  5%
# [libx264 @ 0x134809400] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x134809400] ref P L0: 50.1%  9.3% 25.0% 15.5%
# [libx264 @ 0x134809400] ref B L0: 89.6%  5.2%  5.2%
# [libx264 @ 0x134809400] ref B L1: 96.4%  3.6%
# [libx264 @ 0x134809400] kb/s:2066.26
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'temp_frames/frame_%04d.png':
#   Duration: 00:00:12.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 640x480 [SAR 3937:3937 DAR 4:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x10f808e00] using SAR=1/1
# [libx264 @ 0x10f808e00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x10f808e00] profile High 4:4:4 Predictive, level 3.1, 4:4:4 8-bit
# [libx264 @ 0x10f808e00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'D1_S2_1.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 640x480 [SAR 1:1 DAR 4:3], q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  301 fps=0.0 q=-1.0 Lsize=    1277kB time=00:00:04.96 bitrate=2105.9kbits/s dup=1 drop=0 speed=6.38x
# video:1273kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.320048%
# [libx264 @ 0x10f808e00] frame I:2     Avg QP:17.77  size: 22493
# [libx264 @ 0x10f808e00] frame P:88    Avg QP:28.51  size:  9057
# [libx264 @ 0x10f808e00] frame B:211   Avg QP:33.93  size:  2183
# [libx264 @ 0x10f808e00] consecutive B-frames:  0.7%  4.7% 38.9% 55.8%
# [libx264 @ 0x10f808e00] mb I  I16..4: 61.4%  0.0% 38.6%
# [libx264 @ 0x10f808e00] mb P  I16..4:  0.9%  0.0%  2.4%  P16..4:  9.1%  9.2% 14.3%  0.0%  0.0%    skip:64.1%
# [libx264 @ 0x10f808e00] mb B  I16..4:  0.2%  0.0%  0.1%  B16..8: 16.0%  7.9%  5.1%  direct: 2.6%  skip:68.1%  L0:50.7% L1:45.1% BI: 4.2%
# [libx264 @ 0x10f808e00] coded y,u,v intra: 42.3% 0.0% 0.0% inter: 8.0% 0.0% 0.0%
# [libx264 @ 0x10f808e00] i16 v,h,dc,p: 66% 15% 19%  0%
# [libx264 @ 0x10f808e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 15% 28%  4%  8%  6%  6%  5%  5%
# [libx264 @ 0x10f808e00] Weighted P-Frames: Y:2.3% UV:0.0%
# [libx264 @ 0x10f808e00] ref P L0: 63.4%  9.0% 16.5% 10.7%  0.3%
# [libx264 @ 0x10f808e00] ref B L0: 77.9% 18.9%  3.2%
# [libx264 @ 0x10f808e00] ref B L1: 92.9%  7.1%
# [libx264 @ 0x10f808e00] kb/s:2077.18
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'temp_frames/frame_%04d.png':
#   Duration: 00:00:12.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 640x480 [SAR 3937:3937 DAR 4:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x13d008e00] using SAR=1/1
# [libx264 @ 0x13d008e00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x13d008e00] profile High 4:4:4 Predictive, level 3.1, 4:4:4 8-bit
# [libx264 @ 0x13d008e00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'D1_S3_1.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 640x480 [SAR 1:1 DAR 4:3], q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  301 fps=0.0 q=-1.0 Lsize=    1384kB time=00:00:04.96 bitrate=2283.0kbits/s dup=1 drop=0 speed=6.32x
# video:1380kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.299681%
# [libx264 @ 0x13d008e00] frame I:2     Avg QP:18.18  size: 22052
# [libx264 @ 0x13d008e00] frame P:169   Avg QP:29.13  size:  6740
# [libx264 @ 0x13d008e00] frame B:130   Avg QP:34.04  size:  1765
# [libx264 @ 0x13d008e00] consecutive B-frames: 19.3% 65.8% 11.0%  4.0%
# [libx264 @ 0x13d008e00] mb I  I16..4: 61.5%  0.0% 38.5%
# [libx264 @ 0x13d008e00] mb P  I16..4:  0.9%  0.0%  1.4%  P16..4: 10.8%  8.7% 12.2%  0.0%  0.0%    skip:66.0%
# [libx264 @ 0x13d008e00] mb B  I16..4:  0.3%  0.0%  0.1%  B16..8: 15.6%  6.9%  4.5%  direct: 2.3%  skip:70.4%  L0:50.2% L1:46.1% BI: 3.7%
# [libx264 @ 0x13d008e00] coded y,u,v intra: 36.9% 0.0% 0.0% inter: 9.1% 0.0% 0.0%
# [libx264 @ 0x13d008e00] i16 v,h,dc,p: 62% 19% 19%  0%
# [libx264 @ 0x13d008e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 14% 32%  4%  8%  6%  5%  5%  5%
# [libx264 @ 0x13d008e00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x13d008e00] ref P L0: 65.8%  7.0% 17.5%  9.7%
# [libx264 @ 0x13d008e00] ref B L0: 72.3% 26.5%  1.2%
# [libx264 @ 0x13d008e00] ref B L1: 99.7%  0.3%
# [libx264 @ 0x13d008e00] kb/s:2252.48
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'temp_frames/frame_%04d.png':
#   Duration: 00:00:12.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 640x480 [SAR 3937:3937 DAR 4:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x12880ea00] using SAR=1/1
# [libx264 @ 0x12880ea00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12880ea00] profile High 4:4:4 Predictive, level 3.1, 4:4:4 8-bit
# [libx264 @ 0x12880ea00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'D1_S4_1.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 640x480 [SAR 1:1 DAR 4:3], q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  301 fps=0.0 q=-1.0 Lsize=    1563kB time=00:00:04.96 bitrate=2577.3kbits/s dup=1 drop=0 speed=6.27x
# video:1560kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.184519%
# [libx264 @ 0x12880ea00] frame I:2     Avg QP:18.90  size: 20864
# [libx264 @ 0x12880ea00] frame P:259   Avg QP:29.48  size:  5698
# [libx264 @ 0x12880ea00] frame B:40    Avg QP:33.87  size:  1974
# [libx264 @ 0x12880ea00] consecutive B-frames: 74.4% 22.6%  3.0%  0.0%
# [libx264 @ 0x12880ea00] mb I  I16..4: 61.8%  0.0% 38.2%
# [libx264 @ 0x12880ea00] mb P  I16..4:  0.9%  0.0%  1.0%  P16..4: 13.0%  9.1% 11.0%  0.0%  0.0%    skip:64.9%
# [libx264 @ 0x12880ea00] mb B  I16..4:  0.3%  0.0%  0.1%  B16..8: 15.8%  8.6%  5.0%  direct: 2.5%  skip:67.8%  L0:56.2% L1:40.5% BI: 3.3%
# [libx264 @ 0x12880ea00] coded y,u,v intra: 33.6% 0.0% 0.0% inter: 11.5% 0.0% 0.0%
# [libx264 @ 0x12880ea00] i16 v,h,dc,p: 59% 22% 19%  0%
# [libx264 @ 0x12880ea00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 15% 35%  3%  7%  5%  5%  4%  4%
# [libx264 @ 0x12880ea00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x12880ea00] ref P L0: 49.1%  7.1% 33.4% 10.4%
# [libx264 @ 0x12880ea00] ref B L0: 57.7% 41.4%  0.9%
# [libx264 @ 0x12880ea00] kb/s:2545.83
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'temp_frames/frame_%04d.png':
#   Duration: 00:00:12.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 640x480 [SAR 3937:3937 DAR 4:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x137809400] using SAR=1/1
# [libx264 @ 0x137809400] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x137809400] profile High 4:4:4 Predictive, level 3.1, 4:4:4 8-bit
# [libx264 @ 0x137809400] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'D2_S1_1.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 640x480 [SAR 1:1 DAR 4:3], q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  301 fps=0.0 q=-1.0 Lsize=    1271kB time=00:00:04.96 bitrate=2096.0kbits/s dup=1 drop=0 speed=6.25x
# video:1266kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.345071%
# [libx264 @ 0x137809400] frame I:2     Avg QP:16.92  size: 24416
# [libx264 @ 0x137809400] frame P:76    Avg QP:27.63  size: 10926
# [libx264 @ 0x137809400] frame B:223   Avg QP:33.99  size:  1870
# [libx264 @ 0x137809400] consecutive B-frames:  1.0%  0.7%  0.0% 98.3%
# [libx264 @ 0x137809400] mb I  I16..4: 61.4%  0.0% 38.6%
# [libx264 @ 0x137809400] mb P  I16..4:  0.8%  0.0%  1.3%  P16..4:  7.5% 11.3% 17.0%  0.0%  0.0%    skip:62.2%
# [libx264 @ 0x137809400] mb B  I16..4:  0.1%  0.0%  0.0%  B16..8: 14.2%  7.9%  5.1%  direct: 3.5%  skip:69.2%  L0:46.3% L1:45.0% BI: 8.8%
# [libx264 @ 0x137809400] coded y,u,v intra: 36.2% 0.0% 0.0% inter: 7.8% 0.0% 0.0%
# [libx264 @ 0x137809400] i16 v,h,dc,p: 76%  9% 15%  0%
# [libx264 @ 0x137809400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 16% 26%  4%  8%  6%  6%  5%  6%
# [libx264 @ 0x137809400] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x137809400] ref P L0: 50.4%  9.6% 24.8% 15.3%
# [libx264 @ 0x137809400] ref B L0: 89.5%  5.1%  5.4%
# [libx264 @ 0x137809400] ref B L1: 96.7%  3.3%
# [libx264 @ 0x137809400] kb/s:2066.97
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'temp_frames/frame_%04d.png':
#   Duration: 00:00:12.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 640x480 [SAR 3937:3937 DAR 4:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x11f00ea00] using SAR=1/1
# [libx264 @ 0x11f00ea00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x11f00ea00] profile High 4:4:4 Predictive, level 3.1, 4:4:4 8-bit
# [libx264 @ 0x11f00ea00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'D2_S2_1.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 640x480 [SAR 1:1 DAR 4:3], q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  301 fps=0.0 q=-1.0 Lsize=    1285kB time=00:00:04.96 bitrate=2120.3kbits/s dup=1 drop=0 speed=6.56x
# video:1281kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.328879%
# [libx264 @ 0x11f00ea00] frame I:2     Avg QP:17.37  size: 22420
# [libx264 @ 0x11f00ea00] frame P:82    Avg QP:28.35  size:  9384
# [libx264 @ 0x11f00ea00] frame B:217   Avg QP:33.86  size:  2290
# [libx264 @ 0x11f00ea00] consecutive B-frames:  1.0%  2.0% 19.9% 77.1%
# [libx264 @ 0x11f00ea00] mb I  I16..4: 61.3%  0.0% 38.7%
# [libx264 @ 0x11f00ea00] mb P  I16..4:  0.8%  0.0%  2.4%  P16..4:  8.8%  8.9% 14.8%  0.0%  0.0%    skip:64.2%
# [libx264 @ 0x11f00ea00] mb B  I16..4:  0.2%  0.0%  0.1%  B16..8: 15.7%  8.2%  5.5%  direct: 2.7%  skip:67.6%  L0:50.3% L1:45.4% BI: 4.3%
# [libx264 @ 0x11f00ea00] coded y,u,v intra: 41.3% 0.0% 0.0% inter: 8.0% 0.0% 0.0%
# [libx264 @ 0x11f00ea00] i16 v,h,dc,p: 71%  9% 19%  0%
# [libx264 @ 0x11f00ea00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 17% 29%  4%  7%  6%  6%  4%  5%
# [libx264 @ 0x11f00ea00] Weighted P-Frames: Y:1.2% UV:0.0%
# [libx264 @ 0x11f00ea00] ref P L0: 64.6%  9.9% 15.9%  9.6%  0.1%
# [libx264 @ 0x11f00ea00] ref B L0: 77.4% 20.1%  2.5%
# [libx264 @ 0x11f00ea00] ref B L1: 89.7% 10.3%
# [libx264 @ 0x11f00ea00] kb/s:2091.20
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'temp_frames/frame_%04d.png':
#   Duration: 00:00:12.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 640x480 [SAR 3937:3937 DAR 4:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x15c809400] using SAR=1/1
# [libx264 @ 0x15c809400] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x15c809400] profile High 4:4:4 Predictive, level 3.1, 4:4:4 8-bit
# [libx264 @ 0x15c809400] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'D2_S3_1.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 640x480 [SAR 1:1 DAR 4:3], q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  301 fps=0.0 q=-1.0 Lsize=    1405kB time=00:00:04.96 bitrate=2316.6kbits/s dup=1 drop=0 speed=6.65x
# video:1400kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.296451%
# [libx264 @ 0x15c809400] frame I:2     Avg QP:18.32  size: 22170
# [libx264 @ 0x15c809400] frame P:164   Avg QP:29.25  size:  6963
# [libx264 @ 0x15c809400] frame B:135   Avg QP:33.99  size:  1829
# [libx264 @ 0x15c809400] consecutive B-frames: 18.3% 61.1% 14.0%  6.6%
# [libx264 @ 0x15c809400] mb I  I16..4: 61.7%  0.0% 38.3%
# [libx264 @ 0x15c809400] mb P  I16..4:  0.8%  0.0%  1.5%  P16..4: 10.4%  8.7% 12.5%  0.0%  0.0%    skip:66.0%
# [libx264 @ 0x15c809400] mb B  I16..4:  0.3%  0.0%  0.1%  B16..8: 15.2%  7.2%  4.8%  direct: 2.5%  skip:70.0%  L0:50.4% L1:45.4% BI: 4.3%
# [libx264 @ 0x15c809400] coded y,u,v intra: 38.9% 0.0% 0.0% inter: 9.0% 0.0% 0.0%
# [libx264 @ 0x15c809400] i16 v,h,dc,p: 68% 12% 20%  0%
# [libx264 @ 0x15c809400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 17% 32%  3%  7%  5%  6%  4%  5%
# [libx264 @ 0x15c809400] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x15c809400] ref P L0: 69.0%  7.4% 15.9%  7.7%
# [libx264 @ 0x15c809400] ref B L0: 71.5% 27.7%  0.8%
# [libx264 @ 0x15c809400] ref B L1: 99.6%  0.4%
# [libx264 @ 0x15c809400] kb/s:2285.64
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'temp_frames/frame_%04d.png':
#   Duration: 00:00:12.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 640x480 [SAR 3937:3937 DAR 4:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x12280ea00] using SAR=1/1
# [libx264 @ 0x12280ea00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12280ea00] profile High 4:4:4 Predictive, level 3.1, 4:4:4 8-bit
# [libx264 @ 0x12280ea00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'D2_S4_1.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 640x480 [SAR 1:1 DAR 4:3], q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  301 fps=0.0 q=-1.0 Lsize=    1535kB time=00:00:04.96 bitrate=2532.5kbits/s dup=1 drop=0 speed=6.44x
# video:1532kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.223554%
# [libx264 @ 0x12280ea00] frame I:2     Avg QP:18.75  size: 21028
# [libx264 @ 0x12280ea00] frame P:218   Avg QP:29.47  size:  6258
# [libx264 @ 0x12280ea00] frame B:81    Avg QP:33.72  size:  1996
# [libx264 @ 0x12280ea00] consecutive B-frames: 51.5% 32.6% 15.9%  0.0%
# [libx264 @ 0x12280ea00] mb I  I16..4: 62.0%  0.0% 38.0%
# [libx264 @ 0x12280ea00] mb P  I16..4:  0.9%  0.0%  1.5%  P16..4: 12.1%  8.8% 11.1%  0.0%  0.0%    skip:65.6%
# [libx264 @ 0x12280ea00] mb B  I16..4:  0.4%  0.0%  0.1%  B16..8: 15.4%  8.8%  5.1%  direct: 2.5%  skip:67.7%  L0:55.9% L1:39.7% BI: 4.3%
# [libx264 @ 0x12280ea00] coded y,u,v intra: 39.5% 0.0% 0.0% inter: 10.5% 0.0% 0.0%
# [libx264 @ 0x12280ea00] i16 v,h,dc,p: 62% 15% 23%  0%
# [libx264 @ 0x12280ea00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 17% 32%  3%  7%  5%  6%  4%  5%
# [libx264 @ 0x12280ea00] Weighted P-Frames: Y:0.5% UV:0.0%
# [libx264 @ 0x12280ea00] ref P L0: 57.1%  8.3% 26.7%  7.8%  0.1%
# [libx264 @ 0x12280ea00] ref B L0: 61.8% 37.0%  1.2%
# [libx264 @ 0x12280ea00] kb/s:2500.58
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'temp_frames/frame_%04d.png':
#   Duration: 00:00:12.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 640x480 [SAR 3937:3937 DAR 4:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x14b00a000] using SAR=1/1
# [libx264 @ 0x14b00a000] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x14b00a000] profile High 4:4:4 Predictive, level 3.1, 4:4:4 8-bit
# [libx264 @ 0x14b00a000] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'D3_S1_1.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 640x480 [SAR 1:1 DAR 4:3], q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  301 fps=0.0 q=-1.0 Lsize=    1271kB time=00:00:04.96 bitrate=2096.7kbits/s dup=1 drop=0 speed=6.54x
# video:1267kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.343732%
# [libx264 @ 0x14b00a000] frame I:2     Avg QP:17.20  size: 25190
# [libx264 @ 0x14b00a000] frame P:76    Avg QP:28.01  size: 10928
# [libx264 @ 0x14b00a000] frame B:223   Avg QP:33.85  size:  1864
# [libx264 @ 0x14b00a000] consecutive B-frames:  0.7%  0.7%  3.0% 95.7%
# [libx264 @ 0x14b00a000] mb I  I16..4: 61.0%  0.0% 39.0%
# [libx264 @ 0x14b00a000] mb P  I16..4:  0.7%  0.0%  1.3%  P16..4:  7.6% 11.1% 17.4%  0.0%  0.0%    skip:61.9%
# [libx264 @ 0x14b00a000] mb B  I16..4:  0.1%  0.0%  0.0%  B16..8: 14.2%  7.9%  5.0%  direct: 3.5%  skip:69.2%  L0:46.5% L1:44.8% BI: 8.7%
# [libx264 @ 0x14b00a000] coded y,u,v intra: 36.6% 0.0% 0.0% inter: 8.0% 0.0% 0.0%
# [libx264 @ 0x14b00a000] i16 v,h,dc,p: 76% 10% 14%  0%
# [libx264 @ 0x14b00a000] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 15% 25%  4%  8%  6%  6%  5%  5%
# [libx264 @ 0x14b00a000] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x14b00a000] ref P L0: 49.7%  9.5% 24.7% 16.0%
# [libx264 @ 0x14b00a000] ref B L0: 89.4%  5.4%  5.2%
# [libx264 @ 0x14b00a000] ref B L1: 96.5%  3.5%
# [libx264 @ 0x14b00a000] kb/s:2067.60
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'temp_frames/frame_%04d.png':
#   Duration: 00:00:12.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 640x480 [SAR 3937:3937 DAR 4:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x14200ea00] using SAR=1/1
# [libx264 @ 0x14200ea00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x14200ea00] profile High 4:4:4 Predictive, level 3.1, 4:4:4 8-bit
# [libx264 @ 0x14200ea00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'D3_S2_1.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 640x480 [SAR 1:1 DAR 4:3], q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  301 fps=0.0 q=-1.0 Lsize=    1296kB time=00:00:04.96 bitrate=2137.0kbits/s dup=1 drop=0 speed=6.72x
# video:1292kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.315379%
# [libx264 @ 0x14200ea00] frame I:2     Avg QP:17.46  size: 22756
# [libx264 @ 0x14200ea00] frame P:87    Avg QP:28.97  size:  9206
# [libx264 @ 0x14200ea00] frame B:212   Avg QP:33.95  size:  2242
# [libx264 @ 0x14200ea00] consecutive B-frames:  1.0%  2.7% 37.9% 58.5%
# [libx264 @ 0x14200ea00] mb I  I16..4: 61.4%  0.0% 38.6%
# [libx264 @ 0x14200ea00] mb P  I16..4:  0.8%  0.0%  2.4%  P16..4:  8.9%  9.2% 14.7%  0.0%  0.0%    skip:64.0%
# [libx264 @ 0x14200ea00] mb B  I16..4:  0.2%  0.0%  0.1%  B16..8: 16.0%  7.8%  5.4%  direct: 2.7%  skip:67.8%  L0:50.6% L1:45.0% BI: 4.4%
# [libx264 @ 0x14200ea00] coded y,u,v intra: 43.0% 0.0% 0.0% inter: 8.2% 0.0% 0.0%
# [libx264 @ 0x14200ea00] i16 v,h,dc,p: 70% 13% 17%  0%
# [libx264 @ 0x14200ea00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 15% 28%  4%  8%  6%  6%  5%  6%
# [libx264 @ 0x14200ea00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x14200ea00] ref P L0: 64.3%  8.8% 16.4% 10.5%
# [libx264 @ 0x14200ea00] ref B L0: 78.5% 18.4%  3.1%
# [libx264 @ 0x14200ea00] ref B L1: 92.3%  7.7%
# [libx264 @ 0x14200ea00] kb/s:2107.95
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'temp_frames/frame_%04d.png':
#   Duration: 00:00:12.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 640x480 [SAR 3937:3937 DAR 4:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x14000e400] using SAR=1/1
# [libx264 @ 0x14000e400] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x14000e400] profile High 4:4:4 Predictive, level 3.1, 4:4:4 8-bit
# [libx264 @ 0x14000e400] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'D3_S3_1.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 640x480 [SAR 1:1 DAR 4:3], q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  301 fps=0.0 q=-1.0 Lsize=    1433kB time=00:00:04.96 bitrate=2363.5kbits/s dup=1 drop=0 speed=6.54x
# video:1429kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.282864%
# [libx264 @ 0x14000e400] frame I:2     Avg QP:18.47  size: 22006
# [libx264 @ 0x14000e400] frame P:186   Avg QP:29.58  size:  6549
# [libx264 @ 0x14000e400] frame B:113   Avg QP:33.84  size:  1774
# [libx264 @ 0x14000e400] consecutive B-frames: 28.6% 60.5% 11.0%  0.0%
# [libx264 @ 0x14000e400] mb I  I16..4: 61.5%  0.0% 38.5%
# [libx264 @ 0x14000e400] mb P  I16..4:  0.9%  0.0%  1.3%  P16..4: 11.1%  8.8% 11.9%  0.0%  0.0%    skip:66.0%
# [libx264 @ 0x14000e400] mb B  I16..4:  0.3%  0.0%  0.1%  B16..8: 15.7%  7.1%  4.5%  direct: 2.4%  skip:70.0%  L0:51.1% L1:44.6% BI: 4.3%
# [libx264 @ 0x14000e400] coded y,u,v intra: 36.7% 0.0% 0.0% inter: 9.6% 0.0% 0.0%
# [libx264 @ 0x14000e400] i16 v,h,dc,p: 64% 17% 19%  0%
# [libx264 @ 0x14000e400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 15% 31%  4%  7%  6%  5%  4%  5%
# [libx264 @ 0x14000e400] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x14000e400] ref P L0: 64.7%  7.0% 18.4%  9.9%
# [libx264 @ 0x14000e400] ref B L0: 64.0% 34.9%  1.1%
# [libx264 @ 0x14000e400] kb/s:2332.34
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'temp_frames/frame_%04d.png':
#   Duration: 00:00:12.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 640x480 [SAR 3937:3937 DAR 4:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x14400c200] using SAR=1/1
# [libx264 @ 0x14400c200] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x14400c200] profile High 4:4:4 Predictive, level 3.1, 4:4:4 8-bit
# [libx264 @ 0x14400c200] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'D3_S4_1.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 640x480 [SAR 1:1 DAR 4:3], q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  301 fps=0.0 q=-1.0 Lsize=    1587kB time=00:00:04.96 bitrate=2618.3kbits/s dup=1 drop=0 speed=6.49x
# video:1585kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.164340%
# [libx264 @ 0x14400c200] frame I:2     Avg QP:19.30  size: 20678
# [libx264 @ 0x14400c200] frame P:274   Avg QP:30.13  size:  5591
# [libx264 @ 0x14400c200] frame B:25    Avg QP:33.30  size:  1952
# [libx264 @ 0x14400c200] consecutive B-frames: 83.4% 16.6%  0.0%  0.0%
# [libx264 @ 0x14400c200] mb I  I16..4: 61.6%  0.0% 38.4%
# [libx264 @ 0x14400c200] mb P  I16..4:  0.9%  0.0%  1.0%  P16..4: 13.4%  9.2% 10.9%  0.0%  0.0%    skip:64.6%
# [libx264 @ 0x14400c200] mb B  I16..4:  0.3%  0.0%  0.1%  B16..8: 15.5%  8.2%  4.9%  direct: 2.4%  skip:68.5%  L0:55.1% L1:41.6% BI: 3.3%
# [libx264 @ 0x14400c200] coded y,u,v intra: 33.0% 0.0% 0.0% inter: 11.7% 0.0% 0.0%
# [libx264 @ 0x14400c200] i16 v,h,dc,p: 61% 17% 22%  0%
# [libx264 @ 0x14400c200] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 15% 34%  3%  7%  5%  5%  4%  4%
# [libx264 @ 0x14400c200] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x14400c200] ref P L0: 48.3%  6.6% 34.2% 10.8%
# [libx264 @ 0x14400c200] ref B L0: 56.4% 43.6%
# [libx264 @ 0x14400c200] kb/s:2586.87
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'temp_frames/frame_%04d.png':
#   Duration: 00:00:12.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 640x480 [SAR 3937:3937 DAR 4:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x12080ea00] using SAR=1/1
# [libx264 @ 0x12080ea00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12080ea00] profile High 4:4:4 Predictive, level 3.1, 4:4:4 8-bit
# [libx264 @ 0x12080ea00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'D4_S1_1.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 640x480 [SAR 1:1 DAR 4:3], q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  301 fps=0.0 q=-1.0 Lsize=    1257kB time=00:00:04.96 bitrate=2074.0kbits/s dup=1 drop=0 speed= 6.7x
# video:1253kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.347494%
# [libx264 @ 0x12080ea00] frame I:2     Avg QP:16.92  size: 24704
# [libx264 @ 0x12080ea00] frame P:76    Avg QP:27.51  size: 10749
# [libx264 @ 0x12080ea00] frame B:223   Avg QP:33.93  size:  1866
# [libx264 @ 0x12080ea00] consecutive B-frames:  0.7%  0.7%  3.0% 95.7%
# [libx264 @ 0x12080ea00] mb I  I16..4: 61.5%  0.0% 38.5%
# [libx264 @ 0x12080ea00] mb P  I16..4:  0.9%  0.0%  1.3%  P16..4:  7.6% 11.3% 16.9%  0.0%  0.0%    skip:62.0%
# [libx264 @ 0x12080ea00] mb B  I16..4:  0.2%  0.0%  0.0%  B16..8: 14.2%  8.1%  4.9%  direct: 3.5%  skip:69.2%  L0:46.8% L1:44.5% BI: 8.7%
# [libx264 @ 0x12080ea00] coded y,u,v intra: 34.3% 0.0% 0.0% inter: 7.7% 0.0% 0.0%
# [libx264 @ 0x12080ea00] i16 v,h,dc,p: 72% 11% 17%  0%
# [libx264 @ 0x12080ea00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 15% 27%  4%  8%  6%  6%  5%  6%
# [libx264 @ 0x12080ea00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x12080ea00] ref P L0: 50.7%  9.1% 24.2% 15.9%
# [libx264 @ 0x12080ea00] ref B L0: 89.3%  5.5%  5.2%
# [libx264 @ 0x12080ea00] ref B L1: 96.8%  3.2%
# [libx264 @ 0x12080ea00] kb/s:2045.20
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'temp_frames/frame_%04d.png':
#   Duration: 00:00:12.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 640x480 [SAR 3937:3937 DAR 4:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x117008e00] using SAR=1/1
# [libx264 @ 0x117008e00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x117008e00] profile High 4:4:4 Predictive, level 3.1, 4:4:4 8-bit
# [libx264 @ 0x117008e00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'D4_S2_1.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 640x480 [SAR 1:1 DAR 4:3], q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  301 fps=0.0 q=-1.0 Lsize=    1302kB time=00:00:04.96 bitrate=2146.8kbits/s dup=1 drop=0 speed=6.54x
# video:1297kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.316339%
# [libx264 @ 0x117008e00] frame I:2     Avg QP:17.50  size: 22264
# [libx264 @ 0x117008e00] frame P:88    Avg QP:28.49  size:  9143
# [libx264 @ 0x117008e00] frame B:211   Avg QP:33.92  size:  2270
# [libx264 @ 0x117008e00] consecutive B-frames:  0.7%  6.0% 34.9% 58.5%
# [libx264 @ 0x117008e00] mb I  I16..4: 61.6%  0.0% 38.4%
# [libx264 @ 0x117008e00] mb P  I16..4:  0.9%  0.0%  2.5%  P16..4:  9.0%  9.4% 14.3%  0.0%  0.0%    skip:64.0%
# [libx264 @ 0x117008e00] mb B  I16..4:  0.2%  0.0%  0.1%  B16..8: 15.9%  8.2%  5.3%  direct: 2.6%  skip:67.7%  L0:50.7% L1:45.0% BI: 4.3%
# [libx264 @ 0x117008e00] coded y,u,v intra: 42.1% 0.0% 0.0% inter: 8.0% 0.0% 0.0%
# [libx264 @ 0x117008e00] i16 v,h,dc,p: 68% 13% 19%  0%
# [libx264 @ 0x117008e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 16% 29%  4%  8%  6%  6%  5%  6%
# [libx264 @ 0x117008e00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x117008e00] ref P L0: 64.1%  8.5% 17.3% 10.1%
# [libx264 @ 0x117008e00] ref B L0: 78.3% 18.6%  3.0%
# [libx264 @ 0x117008e00] ref B L1: 92.3%  7.7%
# [libx264 @ 0x117008e00] kb/s:2117.68
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'temp_frames/frame_%04d.png':
#   Duration: 00:00:12.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 640x480 [SAR 3937:3937 DAR 4:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x12380c200] using SAR=1/1
# [libx264 @ 0x12380c200] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12380c200] profile High 4:4:4 Predictive, level 3.1, 4:4:4 8-bit
# [libx264 @ 0x12380c200] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'D4_S3_1.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 640x480 [SAR 1:1 DAR 4:3], q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  301 fps=0.0 q=-1.0 Lsize=    1403kB time=00:00:04.96 bitrate=2313.4kbits/s dup=1 drop=0 speed=5.25x
# video:1399kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.291252%
# [libx264 @ 0x12380c200] frame I:2     Avg QP:18.94  size: 21795
# [libx264 @ 0x12380c200] frame P:178   Avg QP:29.11  size:  6588
# [libx264 @ 0x12380c200] frame B:121   Avg QP:33.98  size:  1778
# [libx264 @ 0x12380c200] consecutive B-frames: 24.3% 62.5% 12.0%  1.3%
# [libx264 @ 0x12380c200] mb I  I16..4: 61.9%  0.0% 38.1%
# [libx264 @ 0x12380c200] mb P  I16..4:  0.8%  0.0%  1.3%  P16..4: 10.6%  8.7% 12.4%  0.0%  0.0%    skip:66.2%
# [libx264 @ 0x12380c200] mb B  I16..4:  0.3%  0.0%  0.1%  B16..8: 15.4%  7.3%  4.6%  direct: 2.4%  skip:70.0%  L0:50.5% L1:45.2% BI: 4.3%
# [libx264 @ 0x12380c200] coded y,u,v intra: 37.1% 0.0% 0.0% inter: 9.2% 0.0% 0.0%
# [libx264 @ 0x12380c200] i16 v,h,dc,p: 64% 17% 19%  0%
# [libx264 @ 0x12380c200] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 16% 33%  3%  7%  5%  5%  4%  5%
# [libx264 @ 0x12380c200] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x12380c200] ref P L0: 64.9%  7.2% 18.4%  9.5%
# [libx264 @ 0x12380c200] ref B L0: 68.3% 30.7%  1.0%
# [libx264 @ 0x12380c200] ref B L1: 99.9%  0.1%
# [libx264 @ 0x12380c200] kb/s:2282.66
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'temp_frames/frame_%04d.png':
#   Duration: 00:00:12.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 640x480 [SAR 3937:3937 DAR 4:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x12300e400] using SAR=1/1
# [libx264 @ 0x12300e400] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12300e400] profile High 4:4:4 Predictive, level 3.1, 4:4:4 8-bit
# [libx264 @ 0x12300e400] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'D4_S4_1.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 640x480 [SAR 1:1 DAR 4:3], q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  301 fps=3.3 q=-1.0 Lsize=    1521kB time=00:00:04.96 bitrate=2508.0kbits/s dup=1 drop=0 speed=0.0543x
# video:1517kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.206647%
# [libx264 @ 0x12300e400] frame I:2     Avg QP:19.04  size: 20878
# [libx264 @ 0x12300e400] frame P:241   Avg QP:29.66  size:  5783
# [libx264 @ 0x12300e400] frame B:58    Avg QP:33.66  size:  2028
# [libx264 @ 0x12300e400] consecutive B-frames: 63.5% 30.6%  6.0%  0.0%
# [libx264 @ 0x12300e400] mb I  I16..4: 61.8%  0.0% 38.2%
# [libx264 @ 0x12300e400] mb P  I16..4:  0.9%  0.0%  1.2%  P16..4: 12.5%  9.2% 11.0%  0.0%  0.0%    skip:65.2%
# [libx264 @ 0x12300e400] mb B  I16..4:  0.4%  0.0%  0.1%  B16..8: 15.6%  8.7%  5.1%  direct: 2.4%  skip:67.6%  L0:55.3% L1:41.2% BI: 3.5%
# [libx264 @ 0x12300e400] coded y,u,v intra: 34.4% 0.0% 0.0% inter: 10.8% 0.0% 0.0%
# [libx264 @ 0x12300e400] i16 v,h,dc,p: 60% 18% 21%  0%
# [libx264 @ 0x12300e400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 16% 34%  3%  7%  5%  5%  4%  5%
# [libx264 @ 0x12300e400] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x12300e400] ref P L0: 51.7%  7.1% 30.9% 10.3%
# [libx264 @ 0x12300e400] ref B L0: 58.9% 39.9%  1.1%
# [libx264 @ 0x12300e400] kb/s:2476.83

# %%
n_dots = 1000
dot_coh = .9
dot_size = 10
dot_speed = 1
dot_angle = 180

f_name = 'D' + str(angle+1) + '_S' + str(speed+1) + '_' + str(set+1) + '.mp4'

generate_random_dot_motion(n_dots, dot_coh, dot_size, dot_speed, dot_angle, 5, 60, [800, 600], 200, f_name)
# Out:
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'temp_frames/frame_%04d.png':
#   Duration: 00:00:12.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 640x480 [SAR 3937:3937 DAR 4:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x131010400] using SAR=1/1
# [libx264 @ 0x131010400] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x131010400] profile High 4:4:4 Predictive, level 3.1, 4:4:4 8-bit
# [libx264 @ 0x131010400] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'D4_S4_1.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 640x480 [SAR 1:1 DAR 4:3], q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  301 fps=0.0 q=-1.0 Lsize=    1628kB time=00:00:04.96 bitrate=2685.3kbits/s dup=1 drop=0 speed=6.19x
# video:1626kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.126544%
# [libx264 @ 0x131010400] frame I:2     Avg QP:18.32  size: 26013
# [libx264 @ 0x131010400] frame P:298   Avg QP:27.86  size:  5410
# [libx264 @ 0x131010400] frame B:1     Avg QP:16.00  size:   113
# [libx264 @ 0x131010400] consecutive B-frames: 99.3%  0.7%  0.0%  0.0%
# [libx264 @ 0x131010400] mb I  I16..4: 61.7%  0.0% 38.3%
# [libx264 @ 0x131010400] mb P  I16..4:  0.6%  0.0%  0.1%  P16..4: 13.0%  9.2% 11.5%  0.0%  0.0%    skip:65.6%
# [libx264 @ 0x131010400] mb B  I16..4:  0.2%  0.0%  0.0%  B16..8:  8.8%  0.2%  0.0%  direct: 0.1%  skip:90.8%  L0:90.2% L1: 9.8% BI: 0.0%
# [libx264 @ 0x131010400] coded y,u,v intra: 17.2% 0.0% 0.0% inter: 16.3% 0.0% 0.0%
# [libx264 @ 0x131010400] i16 v,h,dc,p: 68% 18% 14%  0%
# [libx264 @ 0x131010400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30% 16% 23%  4%  6%  6%  5%  5%  5%
# [libx264 @ 0x131010400] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x131010400] ref P L0: 77.0%  7.0% 11.6%  4.5%
# [libx264 @ 0x131010400] kb/s:2654.13
